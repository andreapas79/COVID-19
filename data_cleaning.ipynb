# %% [markdown]
# # Import block

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Demographic Data

# %%
df_demo = pd.read_csv('Data/demographic_data/Regions.csv')

# %%
df_demo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             21 non-null     int64
#  1   denominazione_regione  21 non-null     object
#  2   popolazione            21 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 632.0+ bytes

# %%
df_demo.head(3)
# Out:
#    Unnamed: 0 denominazione_regione  popolazione
# 0           0               Abruzzo      1311580
# 1           1            Basilicata       562869
# 2           2          P.A. Bolzano       531178

# %% [markdown]
# Qui si tratta semplicemente di eliminare la prima colonna, in quanto è un vecchio indice

# %% [markdown]
# Here it is simply a matter of removing the first column, it is just an old index

# %%
df_demo.drop('Unnamed: 0', axis=1, inplace = True)

# %%
df_demo.head(3)
# Out:
#   denominazione_regione  popolazione
# 0               Abruzzo      1311580
# 1            Basilicata       562869
# 2          P.A. Bolzano       531178

# %% [markdown]
# # Covid-19 Data

# %%
df_covid = pd.read_csv('https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-regioni/dpc-covid19-ita-regioni-latest.csv')

# %%
df_covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   data                         21 non-null     object
#  1   stato                        21 non-null     object
#  2   codice_regione               21 non-null     int64
#  3   denominazione_regione        21 non-null     object
#  4   lat                          21 non-null     float64
#  5   long                         21 non-null     float64
#  6   ricoverati_con_sintomi       21 non-null     int64
#  7   terapia_intensiva            21 non-null     int64
#  8   totale_ospedalizzati         21 non-null     int64
#  9   isolamento_domiciliare       21 non-null     int64
#  10  totale_attualmente_positivi  21 non-null     int64
#  11  nuovi_attualmente_positivi   21 non-null     int64
#  12  dimessi_guariti              21 non-null     int64
#  13  deceduti                     21 non-null     int64
#  14  totale_casi                  21 non-null     int64
#  15  tamponi                      21 non-null     int64
#  16  note_it                      0 non-null      float64
#  17  note_en                      0 non-null      float64
# dtypes: float64(4), int64(11), object(3)
# memory usage: 3.1+ KB

# %%
df_covid.head(3)
# Out:
#                   data stato  codice_regione denominazione_regione        lat  \
# 0  2020-03-28T17:00:00   ITA              13               Abruzzo  42.351222
# 1  2020-03-28T17:00:00   ITA              17            Basilicata  40.639471
# 2  2020-03-28T17:00:00   ITA               4          P.A. Bolzano  46.499335
#
#         long  ricoverati_con_sintomi  terapia_intensiva  totale_ospedalizzati  \
# 0  13.398438                     311                 70                   381
# 1  15.805148                      26                 19                    45
# 2  11.356624                     225                 51                   276
#
#    isolamento_domiciliare  totale_attualmente_positivi  \
# 0                     646                         1027
# 1                     133                          178
# 2                     653                          929
#
#    nuovi_attualmente_positivi  dimessi_guariti  deceduti  totale_casi  \
# 0                         102               30        76         1133
# 1                          31                1         3          182
# 2                          96              116        64         1109
#
#    tamponi  note_it  note_en
# 0     7003      NaN      NaN
# 1     1421      NaN      NaN
# 2     9168      NaN      NaN

# %% [markdown]
# Qui va tutto bene, nella prossima fase deciderò come strutturare il dataframe di analisi.

# %% [markdown]
# Everything is fine here, in the next phase I will decide how to structure the analysis dataframe.

# %% [markdown]
# # Air Pollution Data

# %%
df_air = pd.read_excel('Data/air_pollution_data/Tabella 3.xlsx', header=1)

# %%
df_air.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Codice zona                79 non-null     object
#  1   id                         79 non-null     int64
#  2   Regione                    79 non-null     object
#  3   Tipo zona                  79 non-null     object
#  4   classificazione            79 non-null     object
#  5   superamento VL             79 non-null     object
#  6   max media annuale (mg/m3)  79 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 4.4+ KB

# %%
df_air.head(3)
# Out:
#   Codice zona  id   Regione    Tipo zona classificazione superamento VL   \
# 0      IT0118   1  PIEMONTE  Agglomerato        aboveUAT              Sì
# 1      IT0119   1  PIEMONTE      Pianura        aboveUAT              No
# 2      IT0120   1  PIEMONTE      Collina        aboveUAT              No
#
#   max media annuale (mg/m3)
# 0                        29
# 1                        24
# 2                        22

# %% [markdown]
# Come si può notare ho due problemi principali, i nomi delle regioni non sono uguali (maiuscolo vs capitalized), bisogna verificare se i codici regione lo sono, la colonna 'max media annuale (mg/m3)' non è identificata come tipo numerico, molto probabilmente ci sono dei valori non numerici nella colonna

# %% [markdown]
# As you can see I have two main problems, the names of the regions is not the same (uppercase vs capitalized), you have to check if the region codes are, the column 'max annual average (mg / m3)' is not identified as a numeric type, most likely there are some non-numeric values in the column

# %%
df_air[df_air['max media annuale (mg/m3)'].str.contains('n', na=False)]
# Out:
#    Codice zona  id  Regione            Tipo zona classificazione  \
# 70      IT1911  19  SICILIA  Agglomerato Palermo        aboveUAT
# 71      IT1912  19  SICILIA  Agglomerato Catania        aboveUAT
# 72      IT1913  19  SICILIA  Agglomerato Messina        aboveUAT
# 74      IT1915  19  SICILIA                Altro        aboveUAT
#
#    superamento VL  max media annuale (mg/m3)
# 70            n.d.                      n.d.
# 71            n.d.                      n.d.
# 72            n.d.                      n.d.
# 74            n.d.                      n.d.

# %% [markdown]
# Una volta trovati l'etichetta per i valori assenti procedo ad eliminare le righe, e mi assicuro vi siano ancora valori validi per la regione

# %% [markdown]
# Once I have found the label for the absent values I proceed to delete the lines, and I make sure there are still valid values for the region

# %%
df_air.drop(df_air[df_air['max media annuale (mg/m3)']=='n.d.'].index, inplace=True)

# %%
df_air[df_air['Regione']=='SICILIA']
# Out:
#    Codice zona  id  Regione         Tipo zona classificazione superamento VL   \
# 73      IT1914  19  SICILIA  Aree Industriali         LAT-UAT              No
#
#    max media annuale (mg/m3)
# 73                        16

# %%
df_air.groupby(['id','Regione']).count()
# Out:
#                           Codice zona  Tipo zona  classificazione  \
# id Regione
# 1  PIEMONTE                         4          4                4
# 2  VALLE_AOSTA                      2          2                2
# 3  LOMBARDIA                        7          7                7
# 5  VENETO                           9          9                9
# 6  FRIULI_VENEZIA_GIULIA            3          3                3
# 7  LIGURIA                          6          6                6
# 8  EMILIA_ROMAGNA                   4          4                4
# 9  TOSCANA                          6          6                6
# 10 UMBRIA                           3          3                3
# 11 MARCHE                           2          2                2
# 12 LAZIO                            4          4                4
# 13 ABRUZZO                          3          3                3
# 14 MOLISE                           3          3                3
# 15 CAMPANIA                         3          3                3
# 16 PUGLIA                           4          4                4
# 18 CALABRIA                         4          4                4
# 19 SICILIA                          1          1                1
# 20 SARDEGNA                         4          4                4
# 41 PA_BOLZANO                       1          1                1
# 42 PA_TRENTO                        2          2                2
#
#                           superamento VL   max media annuale (mg/m3)
# id Regione
# 1  PIEMONTE                             4                          4
# 2  VALLE_AOSTA                          2                          2
# 3  LOMBARDIA                            7                          7
# 5  VENETO                               9                          9
# 6  FRIULI_VENEZIA_GIULIA                3                          3
# 7  LIGURIA                              6                          6
# 8  EMILIA_ROMAGNA                       4                          4
# 9  TOSCANA                              6                          6
# 10 UMBRIA                               3                          3
# 11 MARCHE                               2                          2
# 12 LAZIO                                4                          4
# 13 ABRUZZO                              3                          3
# 14 MOLISE                               3                          3
# 15 CAMPANIA                             3                          3
# 16 PUGLIA                               4                          4
# 18 CALABRIA                             4                          4
# 19 SICILIA                              1                          1
# 20 SARDEGNA                             4                          4
# 41 PA_BOLZANO                           1                          1
# 42 PA_TRENTO                            2                          2

# %%
df_covid.groupby(['codice_regione', 'denominazione_regione']).count()
# Out:
#                                       data  stato  lat  long  \
# codice_regione denominazione_regione
# 1              Piemonte                  1      1    1     1
# 2              Valle d'Aosta             1      1    1     1
# 3              Lombardia                 1      1    1     1
# 4              P.A. Bolzano              1      1    1     1
#                P.A. Trento               1      1    1     1
# 5              Veneto                    1      1    1     1
# 6              Friuli Venezia Giulia     1      1    1     1
# 7              Liguria                   1      1    1     1
# 8              Emilia Romagna            1      1    1     1
# 9              Toscana                   1      1    1     1
# 10             Umbria                    1      1    1     1
# 11             Marche                    1      1    1     1
# 12             Lazio                     1      1    1     1
# 13             Abruzzo                   1      1    1     1
# 14             Molise                    1      1    1     1
# 15             Campania                  1      1    1     1
# 16             Puglia                    1      1    1     1
# 17             Basilicata                1      1    1     1
# 18             Calabria                  1      1    1     1
# 19             Sicilia                   1      1    1     1
# 20             Sardegna                  1      1    1     1
#
#                                       ricoverati_con_sintomi  \
# codice_regione denominazione_regione
# 1              Piemonte                                    1
# 2              Valle d'Aosta                               1
# 3              Lombardia                                   1
# 4              P.A. Bolzano                                1
#                P.A. Trento                                 1
# 5              Veneto                                      1
# 6              Friuli Venezia Giulia                       1
# 7              Liguria                                     1
# 8              Emilia Romagna                              1
# 9              Toscana                                     1
# 10             Umbria                                      1
# 11             Marche                                      1
# 12             Lazio                                       1
# 13             Abruzzo                                     1
# 14             Molise                                      1
# 15             Campania                                    1
# 16             Puglia                                      1
# 17             Basilicata                                  1
# 18             Calabria                                    1
# 19             Sicilia                                     1
# 20             Sardegna                                    1
#
#                                       terapia_intensiva  totale_ospedalizzati  \
# codice_regione denominazione_regione
# 1              Piemonte                               1                     1
# 2              Valle d'Aosta                          1                     1
# 3              Lombardia                              1                     1
# 4              P.A. Bolzano                           1                     1
#                P.A. Trento                            1                     1
# 5              Veneto                                 1                     1
# 6              Friuli Venezia Giulia                  1                     1
# 7              Liguria                                1                     1
# 8              Emilia Romagna                         1                     1
# 9              Toscana                                1                     1
# 10             Umbria                                 1                     1
# 11             Marche                                 1                     1
# 12             Lazio                                  1                     1
# 13             Abruzzo                                1                     1
# 14             Molise                                 1                     1
# 15             Campania                               1                     1
# 16             Puglia                                 1                     1
# 17             Basilicata                             1                     1
# 18             Calabria                               1                     1
# 19             Sicilia                                1                     1
# 20             Sardegna                               1                     1
#
#                                       isolamento_domiciliare  \
# codice_regione denominazione_regione
# 1              Piemonte                                    1
# 2              Valle d'Aosta                               1
# 3              Lombardia                                   1
# 4              P.A. Bolzano                                1
#                P.A. Trento                                 1
# 5              Veneto                                      1
# 6              Friuli Venezia Giulia                       1
# 7              Liguria                                     1
# 8              Emilia Romagna                              1
# 9              Toscana                                     1
# 10             Umbria                                      1
# 11             Marche                                      1
# 12             Lazio                                       1
# 13             Abruzzo                                     1
# 14             Molise                                      1
# 15             Campania                                    1
# 16             Puglia                                      1
# 17             Basilicata                                  1
# 18             Calabria                                    1
# 19             Sicilia                                     1
# 20             Sardegna                                    1
#
#                                       totale_attualmente_positivi  \
# codice_regione denominazione_regione
# 1              Piemonte                                         1
# 2              Valle d'Aosta                                    1
# 3              Lombardia                                        1
# 4              P.A. Bolzano                                     1
#                P.A. Trento                                      1
# 5              Veneto                                           1
# 6              Friuli Venezia Giulia                            1
# 7              Liguria                                          1
# 8              Emilia Romagna                                   1
# 9              Toscana                                          1
# 10             Umbria                                           1
# 11             Marche                                           1
# 12             Lazio                                            1
# 13             Abruzzo                                          1
# 14             Molise                                           1
# 15             Campania                                         1
# 16             Puglia                                           1
# 17             Basilicata                                       1
# 18             Calabria                                         1
# 19             Sicilia                                          1
# 20             Sardegna                                         1
#
#                                       nuovi_attualmente_positivi  \
# codice_regione denominazione_regione
# 1              Piemonte                                        1
# 2              Valle d'Aosta                                   1
# 3              Lombardia                                       1
# 4              P.A. Bolzano                                    1
#                P.A. Trento                                     1
# 5              Veneto                                          1
# 6              Friuli Venezia Giulia                           1
# 7              Liguria                                         1
# 8              Emilia Romagna                                  1
# 9              Toscana                                         1
# 10             Umbria                                          1
# 11             Marche                                          1
# 12             Lazio                                           1
# 13             Abruzzo                                         1
# 14             Molise                                          1
# 15             Campania                                        1
# 16             Puglia                                          1
# 17             Basilicata                                      1
# 18             Calabria                                        1
# 19             Sicilia                                         1
# 20             Sardegna                                        1
#
#                                       dimessi_guariti  deceduti  totale_casi  \
# codice_regione denominazione_regione
# 1              Piemonte                             1         1            1
# 2              Valle d'Aosta                        1         1            1
# 3              Lombardia                            1         1            1
# 4              P.A. Bolzano                         1         1            1
#                P.A. Trento                          1         1            1
# 5              Veneto                               1         1            1
# 6              Friuli Venezia Giulia                1         1            1
# 7              Liguria                              1         1            1
# 8              Emilia Romagna                       1         1            1
# 9              Toscana                              1         1            1
# 10             Umbria                               1         1            1
# 11             Marche                               1         1            1
# 12             Lazio                                1         1            1
# 13             Abruzzo                              1         1            1
# 14             Molise                               1         1            1
# 15             Campania                             1         1            1
# 16             Puglia                               1         1            1
# 17             Basilicata                           1         1            1
# 18             Calabria                             1         1            1
# 19             Sicilia                              1         1            1
# 20             Sardegna                             1         1            1
#
#                                       tamponi  note_it  note_en
# codice_regione denominazione_regione
# 1              Piemonte                     1        0        0
# 2              Valle d'Aosta                1        0        0
# 3              Lombardia                    1        0        0
# 4              P.A. Bolzano                 1        0        0
#                P.A. Trento                  1        0        0
# 5              Veneto                       1        0        0
# 6              Friuli Venezia Giulia        1        0        0
# 7              Liguria                      1        0        0
# 8              Emilia Romagna               1        0        0
# 9              Toscana                      1        0        0
# 10             Umbria                       1        0        0
# 11             Marche                       1        0        0
# 12             Lazio                        1        0        0
# 13             Abruzzo                      1        0        0
# 14             Molise                       1        0        0
# 15             Campania                     1        0        0
# 16             Puglia                       1        0        0
# 17             Basilicata                   1        0        0
# 18             Calabria                     1        0        0
# 19             Sicilia                      1        0        0
# 20             Sardegna                     1        0        0

# %%
df_demo
# Out:
#     denominazione_regione  popolazione
# 0                 Abruzzo      1311580
# 1              Basilicata       562869
# 2            P.A. Bolzano       531178
# 3                Calabria      1947131
# 4                Campania      5801692
# 5          Emilia Romagna      4459477
# 6   Friuli Venezia Giulia      1215220
# 7                   Lazio      4459477
# 8                 Liguria      1550640
# 9               Lombardia     10060574
# 10                 Marche      1525271
# 11                 Molise       305617
# 12               Piemonte      4356406
# 13                 Puglia      4029053
# 14               Sardegna      1639591
# 15                Sicilia      4999891
# 16                Toscana      3729641
# 17            P.A. Trento       541098
# 18                 Umbria       882015
# 19          Valle d'Aosta       125666
# 20                 Veneto      4905854

# %% [markdown]
# I codici regione non corrispondono tra il dataframe del covid e quelli dell'inquinamento, e sono totalmente assenti nel dataframe del indice demografico, mentre i nomi delle regioni sono uguali tra Covid e Indice Demografico. Visto che gli eventuali dati da aggiornare saranno quelli del Covid, manterrò questa nomenclatura come corretta. Modificherò i nomi delle regioni nel dataframe dell'inquinamento, e userò questo campo per fare il join dei dati. In più manca una regione (la Basilicata) sempre nel dataframe dell'inquinamento.

# %% [markdown]
# The region codes do not correspond between the covid and pollution dataframes, and they are totally absent in the demographic index dataframe, while the names of the regions are the same between Covid and Demographic Index. Since any data to be updated will be that of Covid, I will keep this nomenclature as correct. I will modify the names of the regions in the pollution dataframe, and I will use this field to join the data. In addition, a region (Basilicata) is still missing in the pollution dataframe.

# %%
df_air['Regione'] = df_air.iloc[:,2].str.replace('_', ' ')
df_air['Regione'] = df_air.iloc[:,2].str.replace('PA ', 'P.A. ')
df_air['Regione'] = df_air.iloc[:,2].apply(str.title)

# %%
df_air.groupby('Regione').count().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, Abruzzo to Veneto
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Codice zona                20 non-null     int64
#  1   id                         20 non-null     int64
#  2   Tipo zona                  20 non-null     int64
#  3   classificazione            20 non-null     int64
#  4   superamento VL             20 non-null     int64
#  5   max media annuale (mg/m3)  20 non-null     int64
# dtypes: int64(6)
# memory usage: 1.1+ KB

# %% [markdown]
# Aggiungo i dati relativi alla Basilicata

# %% [markdown]
# Adding Basilicata's Data

# %%
df_air2 = pd.read_excel('Data/air_pollution_data/Tabella 2.xlsx', header=1)
df_basilicata = df_air2[df_air2['Regione']=='Basilicata']
df_basilicata
# Out:
#      Region_id  Province_id  Municipality_id  Observation_id  Station_code  \
# 246       17.0           76         17076048           28804       1707620
# 247       17.0           76         17076098           28809       1707625
# 248       17.0           76         17076037           28810       1707622
# 249       17.0           76         17076098           28811       1707624
# 250       17.0           76         17076098           28812       1707623
#
#     Station_eu_code     Regione Provincia         Comune  \
# 246         IT1740A  Basilicata   Potenza          Melfi
# 247         IT2205A  Basilicata   Potenza       Viggiano
# 248         IT2202A  Basilicata   Potenza  Grumento Nova
# 249         IT2204A  Basilicata   Potenza       Viggiano
# 250         IT2203A  Basilicata   Potenza       Viggiano
#
#                 Nome della stazione  ... Tipo di stazione Tecnica di misura  \
# 246             San Nicola di Melfi  ...       industrial                 b
# 247   VIGGIANO - COSTA MOLINA SUD 1  ...       industrial                 b
# 248                      GRUMENTO 3  ...       industrial                 b
# 249  VIGGIANO - MASSERIA DE BLASIIS  ...       industrial                 b
# 250                      VIGGIANO 1  ...       industrial                 b
#
#     Valore medio annuo1,3 [µg/m³] 50° percentile1 [µg/m3]  \
# 246                            11                 9.48004
# 247                             8                     7.2
# 248                            10                     8.4
# 249                            11                    9.88
# 250                            10                     8.6
#
#     75° percentile2 [µg/m3] 98°  percentile2 [µg/m3]  \
# 246                 13.3713                  26.4319
# 247                    10.2                     20.1
# 248                   11.83                     20.8
# 249                   13.98                    27.14
# 250                   11.54                     21.3
#
#     99,2° percentile2 [µg/m3] Valore massimo2 [µg/m3] Numero di dati validi  \
# 246                   34.0767                 52.8224                   337
# 247                      25.6                    45.6                   352
# 248                      24.8                    55.2                   353
# 249                     34.44                   49.75                   355
# 250                      24.7                    63.9                   357
#
#      AQD used4
# 246          f
# 247          f
# 248          f
# 249          f
# 250          f
#
# [5 rows x 21 columns]

# %%
df_basilicata['Valore medio annuo1,3 [µg/m³]'] = pd.to_numeric(df_basilicata['Valore medio annuo1,3 [µg/m³]'])
df_basilicata.groupby('Regione').mean()
# Out:
# <ipython-input-22-38b0d8420062>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_basilicata['Valore medio annuo1,3 [µg/m³]'] = pd.to_numeric(df_basilicata['Valore medio annuo1,3 [µg/m³]'])
#             Region_id  Province_id  Municipality_id  Observation_id  \
# Regione
# Basilicata       17.0         76.0       17076075.8         28809.2
#
#             Station_code  Valore medio annuo1,3 [µg/m³]  Numero di dati validi
# Regione
# Basilicata     1707622.8                           10.0                  350.8

# %%
data_basilicata=['Not Important',17, 'Basilicata', 'Rurale', 'Not Important', 'No',10]
data_basilicata = pd.DataFrame([pd.Series(data_basilicata)])
data_basilicata.columns = df_air.columns
data_basilicata
# Out:
#      Codice zona  id     Regione Tipo zona classificazione superamento VL   \
# 0  Not Important  17  Basilicata    Rurale   Not Important              No
#
#    max media annuale (mg/m3)
# 0                         10

# %%
df_air = pd.concat([df_air, data_basilicata], ignore_index=True)
df_air
# Out:
#       Codice zona  id      Regione                Tipo zona classificazione  \
# 0          IT0118   1     Piemonte              Agglomerato        aboveUAT
# 1          IT0119   1     Piemonte                  Pianura        aboveUAT
# 2          IT0120   1     Piemonte                  Collina        aboveUAT
# 3          IT0121   1     Piemonte                 montagna         LAT-UAT
# 4          IT0204   2  Valle Aosta          VdA_fondo_valle         LAT-UAT
# ..            ...  ..          ...                      ...             ...
# 71         IT2007  20     Sardegna  Agglomerato di Cagliari         LAT-UAT
# 72         IT2008  20     Sardegna              Zona Urbana         LAT-UAT
# 73         IT2009  20     Sardegna         Zona Industriale         LAT-UAT
# 74         IT2010  20     Sardegna              Zona Rurale        belowLAT
# 75  Not Important  17   Basilicata                   Rurale   Not Important
#
#    superamento VL  max media annuale (mg/m3)
# 0               Sì                        29
# 1               No                        24
# 2               No                        22
# 3               No                        19
# 4               No                        13
# ..             ...                       ...
# 71              No                        14
# 72              No                         6
# 73              No                        15
# 74              No                         6
# 75              No                        10
#
# [76 rows x 7 columns]

# %%
df_air.loc[df_air['Regione']=='Valle Aosta', 'Regione']= "Valle d'Aosta"

# %%
df_air[df_air['Regione']== "Valle d'Aosta"]
# Out:
#   Codice zona  id        Regione           Tipo zona classificazione  \
# 4      IT0204   2  Valle d'Aosta     VdA_fondo_valle         LAT-UAT
# 5      IT0205   2  Valle d'Aosta  VdA_rurale montano        belowLAT
#
#   superamento VL  max media annuale (mg/m3)
# 4              No                        13
# 5              No                        11

# %% [markdown]
# # Exporting tables
# La pulizia dei dataframe è conclusa, esporto le tre tabelle cosi ottenute per comodità di lavoro e passo alla fase successiva

# %% [markdown]
# The cleaning of the dataframe is completed, I export the three tables thus obtained for ease of work and go to the next step

# %%
df_air.to_csv('df_air.csv')
df_demo.to_csv('df_demo.csv')
df_covid.to_csv('df_covid.csv')
