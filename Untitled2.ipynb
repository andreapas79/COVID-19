# %%
# !jupyter nbextension enable --py --sys-prefix ipyleaflet
# !jupyter nbextension enable --py widgetsnbextension --sys-prefix
# Out:
# Enabling notebook extension jupyter-leaflet/extension...
#       - Validating: ok
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: ok

# %%
from ipyleaflet import (Map, DrawControl, basemaps, Circle)
mymap = Map(center=[33.7490,-84.3880],basemap=basemaps.Stamen.Toner , zoom=10)
mymap.layout.height='200px'
mymap
# Out:
# Map(center=[33.749, -84.388], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoo…

# %%
from IPython.display import Image

Image(filename="Images/ipyleaflet-italy.png")

# %%
import folium

# %%
map = folium.Map([51., 12.], zoom_start=6,control_scale=True)
folium.GeoJson(data).add_to(map)
map.save('f.html')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-150514510111> in <module>
#       1 map = folium.Map([51., 12.], zoom_start=6,control_scale=True)
# ----> 2 folium.GeoJson(data).add_to(map)
#       3 map.save('f.html')
#
# NameError: name 'data' is not defined

# %%
import ipyleaflet as ipyl
import ipywidgets as ipyw
import json
import os
import requests

# %%
# Map and label widgets
map = ipyl.Map(center=[53.88, 27.45], zoom=4)
label = ipyw.Label(layout=ipyw.Layout(width='100%'))

# geojson layer with hover handler
if not os.path.exists('Lib/europe_110.geo.json'):
    url = 'https://raw.githubusercontent.com/jupyter-widgets/ipyleaflet/master/examples/europe_110.geo.json'
    r = requests.get(url)
    with open('Lib/europe_110.geo.json', 'w') as f:
        f.write(r.content.decode("utf-8"))
    
with open('Lib/europe_110.geo.json') as f:
    data = json.load(f)
for feature in data['features']:
    feature['properties']['style'] = {
        'color': 'grey',
        'weight': 1,
        'fillColor': 'grey',
        'fillOpacity': 0.5
    }
layer = ipyl.GeoJSON(data=data, hover_style={'fillColor': 'red'})

def hover_handler(event=None, feature=None, id=None, properties=None):
    label.value = properties['geounit']

layer.on_hover(hover_handler)
map.add_layer(layer)


ipyw.VBox([map, label])
